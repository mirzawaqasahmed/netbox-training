# %%
import requests

# %% [markdown]
# # Headers

# %%
headers = {
    'Authorization': 'Token c2832328bb7c5b7ce8fc17139382adadc676a257',
    'Accept': 'application/json',
    'Content-Type': 'application/json'
}

# %% [markdown]
# # Generate Devices

# %%
device_names = ['access-1', 'access-2', 'access-3', 'access-4', 'access-5', 'access-6', 'access-7', 'access-8']
devices = []
for name in device_names:
    device = {
        'name': name,
        'device_type':{
            'model': 'EX4300-48T'
        },
        'site': {
            'name': 'Branch #501'
        },
        'device_role': {
            'name': 'Access Switch'
        }
    }
    devices.append(device)

# %%
devices
# Out:
# [{'name': 'access-1',
#   'device_type': {'model': 'EX4300-48T'},
#   'site': {'name': 'Branch #501'},
#   'device_role': {'name': 'Access Switch'}},
#  {'name': 'access-2',
#   'device_type': {'model': 'EX4300-48T'},
#   'site': {'name': 'Branch #501'},
#   'device_role': {'name': 'Access Switch'}},
#  {'name': 'access-3',
#   'device_type': {'model': 'EX4300-48T'},
#   'site': {'name': 'Branch #501'},
#   'device_role': {'name': 'Access Switch'}},
#  {'name': 'access-4',
#   'device_type': {'model': 'EX4300-48T'},
#   'site': {'name': 'Branch #501'},
#   'device_role': {'name': 'Access Switch'}},
#  {'name': 'access-5',
#   'device_type': {'model': 'EX4300-48T'},
#   'site': {'name': 'Branch #501'},
#   'device_role': {'name': 'Access Switch'}},
#  {'name': 'access-6',
#   'device_type': {'model': 'EX4300-48T'},
#   'site': {'name': 'Branch #501'},
#   'device_role': {'name': 'Access Switch'}},
#  {'name': 'access-7',
#   'device_type': {'model': 'EX4300-48T'},
#   'site': {'name': 'Branch #501'},
#   'device_role': {'name': 'Access Switch'}},
#  {'name': 'access-8',
#   'device_type': {'model': 'EX4300-48T'},
#   'site': {'name': 'Branch #501'},
#   'device_role': {'name': 'Access Switch'}}]

# %% [markdown]
# # Make request to create devices

# %%
response = requests.post('http://localhost:8000/api/dcim/devices/', headers=headers, json=devices)

# %%
response.json()
# Out:
# [{'id': 70,
#   'name': 'access-1',
#   'display_name': 'access-1',
#   'device_type': {'id': 26,
#    'url': 'http://localhost:8000/api/dcim/device-types/26/',
#    'manufacturer': {'id': 13,
#     'url': 'http://localhost:8000/api/dcim/manufacturers/13/',
#     'name': 'Juniper',
#     'slug': 'juniper'},
#    'model': 'EX4300-48T',
#    'slug': 'ex4300-48t',
#    'display_name': 'Juniper EX4300-48T'},
#   'device_role': {'id': 9,
#    'url': 'http://localhost:8000/api/dcim/device-roles/9/',
#    'name': 'Access Switch',
#    'slug': 'access-switch'},
#   'tenant': None,
#   'platform': None,
#   'serial': '',
#   'asset_tag': None,
#   'site': {'id': 76,
#    'url': 'http://localhost:8000/api/dcim/sites/76/',
#    'name': 'Branch #501',
#    'slug': 'branch-501'},
#   'rack': None,
#   'position': None,
#   'face': None,
#   'parent_device': None,
#   'status': {'value': 1, 'label': 'Active'},
#   'primary_ip': None,
#   'primary_ip4': None,
#   'primary_ip6': None,
#   'cluster': None,
#   'virtual_chassis': None,
#   'vc_position': None,
#   'vc_priority': None,
#   'comments': '',
#   'local_context_data': None,
#   'tags': [],
#   'config_context': {},
#   'created': '2019-12-05',
#   'last_updated': '2019-12-05T16:26:41.503199Z'},
#  {'id': 71,
#   'name': 'access-2',
#   'display_name': 'access-2',
#   'device_type': {'id': 26,
#    'url': 'http://localhost:8000/api/dcim/device-types/26/',
#    'manufacturer': {'id': 13,
#     'url': 'http://localhost:8000/api/dcim/manufacturers/13/',
#     'name': 'Juniper',
#     'slug': 'juniper'},
#    'model': 'EX4300-48T',
#    'slug': 'ex4300-48t',
#    'display_name': 'Juniper EX4300-48T'},
#   'device_role': {'id': 9,
#    'url': 'http://localhost:8000/api/dcim/device-roles/9/',
#    'name': 'Access Switch',
#    'slug': 'access-switch'},
#   'tenant': None,
#   'platform': None,
#   'serial': '',
#   'asset_tag': None,
#   'site': {'id': 76,
#    'url': 'http://localhost:8000/api/dcim/sites/76/',
#    'name': 'Branch #501',
#    'slug': 'branch-501'},
#   'rack': None,
#   'position': None,
#   'face': None,
#   'parent_device': None,
#   'status': {'value': 1, 'label': 'Active'},
#   'primary_ip': None,
#   'primary_ip4': None,
#   'primary_ip6': None,
#   'cluster': None,
#   'virtual_chassis': None,
#   'vc_position': None,
#   'vc_priority': None,
#   'comments': '',
#   'local_context_data': None,
#   'tags': [],
#   'config_context': {},
#   'created': '2019-12-05',
#   'last_updated': '2019-12-05T16:26:41.676289Z'},
#  {'id': 72,
#   'name': 'access-3',
#   'display_name': 'access-3',
#   'device_type': {'id': 26,
#    'url': 'http://localhost:8000/api/dcim/device-types/26/',
#    'manufacturer': {'id': 13,
#     'url': 'http://localhost:8000/api/dcim/manufacturers/13/',
#     'name': 'Juniper',
#     'slug': 'juniper'},
#    'model': 'EX4300-48T',
#    'slug': 'ex4300-48t',
#    'display_name': 'Juniper EX4300-48T'},
#   'device_role': {'id': 9,
#    'url': 'http://localhost:8000/api/dcim/device-roles/9/',
#    'name': 'Access Switch',
#    'slug': 'access-switch'},
#   'tenant': None,
#   'platform': None,
#   'serial': '',
#   'asset_tag': None,
#   'site': {'id': 76,
#    'url': 'http://localhost:8000/api/dcim/sites/76/',
#    'name': 'Branch #501',
#    'slug': 'branch-501'},
#   'rack': None,
#   'position': None,
#   'face': None,
#   'parent_device': None,
#   'status': {'value': 1, 'label': 'Active'},
#   'primary_ip': None,
#   'primary_ip4': None,
#   'primary_ip6': None,
#   'cluster': None,
#   'virtual_chassis': None,
#   'vc_position': None,
#   'vc_priority': None,
#   'comments': '',
#   'local_context_data': None,
#   'tags': [],
#   'config_context': {},
#   'created': '2019-12-05',
#   'last_updated': '2019-12-05T16:26:41.945116Z'},
#  {'id': 73,
#   'name': 'access-4',
#   'display_name': 'access-4',
#   'device_type': {'id': 26,
#    'url': 'http://localhost:8000/api/dcim/device-types/26/',
#    'manufacturer': {'id': 13,
#     'url': 'http://localhost:8000/api/dcim/manufacturers/13/',
#     'name': 'Juniper',
#     'slug': 'juniper'},
#    'model': 'EX4300-48T',
#    'slug': 'ex4300-48t',
#    'display_name': 'Juniper EX4300-48T'},
#   'device_role': {'id': 9,
#    'url': 'http://localhost:8000/api/dcim/device-roles/9/',
#    'name': 'Access Switch',
#    'slug': 'access-switch'},
#   'tenant': None,
#   'platform': None,
#   'serial': '',
#   'asset_tag': None,
#   'site': {'id': 76,
#    'url': 'http://localhost:8000/api/dcim/sites/76/',
#    'name': 'Branch #501',
#    'slug': 'branch-501'},
#   'rack': None,
#   'position': None,
#   'face': None,
#   'parent_device': None,
#   'status': {'value': 1, 'label': 'Active'},
#   'primary_ip': None,
#   'primary_ip4': None,
#   'primary_ip6': None,
#   'cluster': None,
#   'virtual_chassis': None,
#   'vc_position': None,
#   'vc_priority': None,
#   'comments': '',
#   'local_context_data': None,
#   'tags': [],
#   'config_context': {},
#   'created': '2019-12-05',
#   'last_updated': '2019-12-05T16:26:42.083323Z'},
#  {'id': 74,
#   'name': 'access-5',
#   'display_name': 'access-5',
#   'device_type': {'id': 26,
#    'url': 'http://localhost:8000/api/dcim/device-types/26/',
#    'manufacturer': {'id': 13,
#     'url': 'http://localhost:8000/api/dcim/manufacturers/13/',
#     'name': 'Juniper',
#     'slug': 'juniper'},
#    'model': 'EX4300-48T',
#    'slug': 'ex4300-48t',
#    'display_name': 'Juniper EX4300-48T'},
#   'device_role': {'id': 9,
#    'url': 'http://localhost:8000/api/dcim/device-roles/9/',
#    'name': 'Access Switch',
#    'slug': 'access-switch'},
#   'tenant': None,
#   'platform': None,
#   'serial': '',
#   'asset_tag': None,
#   'site': {'id': 76,
#    'url': 'http://localhost:8000/api/dcim/sites/76/',
#    'name': 'Branch #501',
#    'slug': 'branch-501'},
#   'rack': None,
#   'position': None,
#   'face': None,
#   'parent_device': None,
#   'status': {'value': 1, 'label': 'Active'},
#   'primary_ip': None,
#   'primary_ip4': None,
#   'primary_ip6': None,
#   'cluster': None,
#   'virtual_chassis': None,
#   'vc_position': None,
#   'vc_priority': None,
#   'comments': '',
#   'local_context_data': None,
#   'tags': [],
#   'config_context': {},
#   'created': '2019-12-05',
#   'last_updated': '2019-12-05T16:26:42.226864Z'},
#  {'id': 75,
#   'name': 'access-6',
#   'display_name': 'access-6',
#   'device_type': {'id': 26,
#    'url': 'http://localhost:8000/api/dcim/device-types/26/',
#    'manufacturer': {'id': 13,
#     'url': 'http://localhost:8000/api/dcim/manufacturers/13/',
#     'name': 'Juniper',
#     'slug': 'juniper'},
#    'model': 'EX4300-48T',
#    'slug': 'ex4300-48t',
#    'display_name': 'Juniper EX4300-48T'},
#   'device_role': {'id': 9,
#    'url': 'http://localhost:8000/api/dcim/device-roles/9/',
#    'name': 'Access Switch',
#    'slug': 'access-switch'},
#   'tenant': None,
#   'platform': None,
#   'serial': '',
#   'asset_tag': None,
#   'site': {'id': 76,
#    'url': 'http://localhost:8000/api/dcim/sites/76/',
#    'name': 'Branch #501',
#    'slug': 'branch-501'},
#   'rack': None,
#   'position': None,
#   'face': None,
#   'parent_device': None,
#   'status': {'value': 1, 'label': 'Active'},
#   'primary_ip': None,
#   'primary_ip4': None,
#   'primary_ip6': None,
#   'cluster': None,
#   'virtual_chassis': None,
#   'vc_position': None,
#   'vc_priority': None,
#   'comments': '',
#   'local_context_data': None,
#   'tags': [],
#   'config_context': {},
#   'created': '2019-12-05',
#   'last_updated': '2019-12-05T16:26:42.361626Z'},
#  {'id': 76,
#   'name': 'access-7',
#   'display_name': 'access-7',
#   'device_type': {'id': 26,
#    'url': 'http://localhost:8000/api/dcim/device-types/26/',
#    'manufacturer': {'id': 13,
#     'url': 'http://localhost:8000/api/dcim/manufacturers/13/',
#     'name': 'Juniper',
#     'slug': 'juniper'},
#    'model': 'EX4300-48T',
#    'slug': 'ex4300-48t',
#    'display_name': 'Juniper EX4300-48T'},
#   'device_role': {'id': 9,
#    'url': 'http://localhost:8000/api/dcim/device-roles/9/',
#    'name': 'Access Switch',
#    'slug': 'access-switch'},
#   'tenant': None,
#   'platform': None,
#   'serial': '',
#   'asset_tag': None,
#   'site': {'id': 76,
#    'url': 'http://localhost:8000/api/dcim/sites/76/',
#    'name': 'Branch #501',
#    'slug': 'branch-501'},
#   'rack': None,
#   'position': None,
#   'face': None,
#   'parent_device': None,
#   'status': {'value': 1, 'label': 'Active'},
#   'primary_ip': None,
#   'primary_ip4': None,
#   'primary_ip6': None,
#   'cluster': None,
#   'virtual_chassis': None,
#   'vc_position': None,
#   'vc_priority': None,
#   'comments': '',
#   'local_context_data': None,
#   'tags': [],
#   'config_context': {},
#   'created': '2019-12-05',
#   'last_updated': '2019-12-05T16:26:42.497814Z'},
#  {'id': 77,
#   'name': 'access-8',
#   'display_name': 'access-8',
#   'device_type': {'id': 26,
#    'url': 'http://localhost:8000/api/dcim/device-types/26/',
#    'manufacturer': {'id': 13,
#     'url': 'http://localhost:8000/api/dcim/manufacturers/13/',
#     'name': 'Juniper',
#     'slug': 'juniper'},
#    'model': 'EX4300-48T',
#    'slug': 'ex4300-48t',
#    'display_name': 'Juniper EX4300-48T'},
#   'device_role': {'id': 9,
#    'url': 'http://localhost:8000/api/dcim/device-roles/9/',
#    'name': 'Access Switch',
#    'slug': 'access-switch'},
#   'tenant': None,
#   'platform': None,
#   'serial': '',
#   'asset_tag': None,
#   'site': {'id': 76,
#    'url': 'http://localhost:8000/api/dcim/sites/76/',
#    'name': 'Branch #501',
#    'slug': 'branch-501'},
#   'rack': None,
#   'position': None,
#   'face': None,
#   'parent_device': None,
#   'status': {'value': 1, 'label': 'Active'},
#   'primary_ip': None,
#   'primary_ip4': None,
#   'primary_ip6': None,
#   'cluster': None,
#   'virtual_chassis': None,
#   'vc_position': None,
#   'vc_priority': None,
#   'comments': '',
#   'local_context_data': None,
#   'tags': [],
#   'config_context': {},
#   'created': '2019-12-05',
#   'last_updated': '2019-12-05T16:26:42.671413Z'}]
